# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import datasets
mass_results = pd.read_csv('mass_results.csv')
mass_results = mass_results.dropna().sort_values(by=['recording']).reset_index(drop=True)

# %%
# preview the data
display(mass_results.head())
print(mass_results['object'].value_counts())
line_pair_3_mean = mass_results.loc[:, 'line_pair_3'].mean()
print(f'\nLine Pair 3 Mean: {line_pair_3_mean}')
print(f'\nNumber of recordings: {len(mass_results)}')
# Out:
#    recording  object  mass result  line_pair_1  line_pair_2  line_pair_3
# 0          1   small    18   pass   110.320326   135.824364   177.809221  \
# 1          2   small    18   pass   105.365589   131.358679   148.441774
# 2          3   small    18   pass   105.337515   131.501001   161.261984
# 3          4  medium    18   pass   110.220289   134.632855   157.828448
# 4          5  medium    18   pass   109.507040   133.908032   154.732961
#
#    line_pair_4  line_pair_5
# 0   131.535798   137.757060
# 1   141.477263   134.106593
# 2   141.512303   134.857544
# 3   137.038248   129.874043
# 4   135.742481   132.175272
# object
# small     18
# medium    15
# large     12
# Name: count, dtype: int64
#
# Line Pair 3 Mean: 172.44460780444442
#
# Number of recordings: 45

# %% [markdown]
# # angles

# %%
# average the angles for each object
average_angles = mass_results.groupby('object').mean([line_pair for line_pair in mass_results.columns if 'line' in line_pair])
average_angles = average_angles.drop(columns=['recording', 'mass'])
x = average_angles.columns
y = average_angles.values
display(average_angles)

# lookup dict fir labelling the plot
objects = { 
    0: 'small (55mm)',
    1: 'medium (60mm)',
    2: 'large (65mm)'
}

# plot the data
for i in range(len(y)):
    plt.plot(x, y[2-i], label=f'{objects[i]}')

# format the plot
plt.legend()
plt.xticks(labels=['1', '2', '3', '4', '5'], ticks=['line_pair_1', 'line_pair_2', 'line_pair_3', 'line_pair_4', 'line_pair_5'])
plt.xlabel('Pivot')
plt.ylabel('Angle (degrees)')
plt.grid(alpha=0.2)
plt.title('Average pivot angle for each container orientation')

plt.savefig('avg_line_pair_angles.png', bbox_inches='tight', dpi=600)

plt.show()
# Out:
#         line_pair_1  line_pair_2  line_pair_3  line_pair_4  line_pair_5
# object
# large    111.134709   144.778823   170.763527   130.088395   125.493995
# medium   109.212798   142.356028   173.387153   134.154501   129.546781
# small    107.463688   141.293691   172.779874   135.849847   134.568290

# %% [markdown]
# # mass

# %%
# copy the data
mass_results_avg = mass_results.copy()

# averate the angles for each object and mass
mass_results_avg = mass_results_avg.groupby(['object', 'mass']).mean(['line_pair_1', 'line_pair_2', 'line_pair_3', 'line_pair_4', 'line_pair_5'])
mass_results_avg.drop(columns=['recording'], inplace=True)
mass_results_avg.reset_index(inplace=True)

mass_results_avg
# Out:
#     object  mass  line_pair_1  line_pair_2  line_pair_3  line_pair_4
# 0    large    18   110.013801   143.465038   155.722128   125.447281  \
# 1    large    32   110.235108   150.025713   176.288588   128.181943
# 2    large    49   111.195142   140.185430   174.765956   131.634334
# 3    large    60   113.094787   145.439109   176.277434   135.090022
# 4   medium    18   109.268976   134.400370   157.984185   136.279399
# 5   medium    32   109.302393   147.080179   177.856384   131.808797
# 6   medium    49   110.253151   143.094569   176.705734   130.278886
# 7   medium    60   108.430668   143.153060   176.190738   137.226513
# 8   medium    63   108.808799   144.051962   178.198725   135.178912
# 9    small    18   107.007810   132.894681   162.504326   138.175121
# 10   small    32   107.193758   138.689033   178.177515   138.129344
# 11   small    49   110.572118   140.384471   178.727425   132.172897
# 12   small    60   103.480570   132.226608   176.934592   143.507868
# 13   small    63   106.575047   148.593307   176.044456   131.126827
# 14   small    65   109.952827   154.974042   164.290929   131.987023
#
#     line_pair_5
# 0    116.690573
# 1    125.375853
# 2    128.307243
# 3    131.602312
# 4    131.322263
# 5    125.544352
# 6    130.925385
# 7    129.818505
# 8    130.123399
# 9    135.573733
# 10   133.536063
# 11   132.678143
# 12   135.477567
# 13   134.276985
# 14   135.867251

# %%
fig, ax = plt.subplots()

def plot_mass_results(data, object):
    ax.set_xlim(56, 66)
    ax.set_ylim(90, 180)
    # for the subset of data where object=='small', plot mass on x axis, angle on y axis, and color code by line pair
    data = data[data['object'] == object]
    colors = {
        'line_pair_1': 'tab:blue',
        'line_pair_2': 'tab:orange',
        'line_pair_3': 'tab:green',
        'line_pair_4': 'tab:red',
        'line_pair_5': 'tab:purple'
    }

    # Set the linestyle for the plot depending on the object with a switch case
    match(object):
        case 'small':
            linestyle = '-'
        case 'medium':
            linestyle = '--'
        case 'large':
            linestyle = ':'

    for line_pair in ['line_pair_1', 'line_pair_2', 'line_pair_3', 'line_pair_4', 'line_pair_5']:
        plt.plot(data['mass'], data[line_pair],
                 label=object + ': ' + 'Pivot ' + line_pair.split('_')[-1], linestyle=linestyle, color=colors[line_pair],
                 marker='o', markersize=3)
        
    ax.legend(title='Pivot', bbox_to_anchor=(1.05, 1), loc='upper left')
    
# Set the x-axis and y-axis labels
ax.set_xlabel('Mass (g)')
ax.set_ylabel('Angle (degrees)')
ax.set_title(f'Mass carried against pivot angle for each container orientation and pivot')
ax.grid(alpha=0.5)

for object in ['small', 'medium', 'large']:
    plot_mass_results(mass_results_avg, object)

# Export the plot as a PNG
plt.savefig('mass_vs_angle.png', bbox_inches='tight', dpi=600)

# Display the plots
plt.show()
